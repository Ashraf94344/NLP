# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# %%
chat = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    google_api_key="AIzaSyBzDu4oT9tbapEY89Uk6_lhvg4ui-REu24",
    temperature=0
)

# %%
message_h = HumanMessage(
    content="I've recently adopted a dog. Can you suggest some dog names?"
)

response = chat.invoke([message_h])

print(response.text)
# Out:
# Congratulations on your new dog! Choosing a name is one of the most fun parts of bringing a new pet home.
#
# To help you narrow it down, I’ve broken these suggestions into a few different "vibes." See if any of these spark a connection:
#
# ### 1. The "Classic & Friendly" Names
# These are timeless, easy to call out at the park, and always sound warm.
# *   **Charlie**
# *   **Daisy**
# *   **Cooper**
# *   **Bella**
# *   **Max**
# *   **Lucy**
# *   **Buddy**
# *   **Sadie**
#
# ### 2. The "Foodie" Names
# Food names are incredibly popular right now because they are usually cute and quirky.
# *   **Olive**
# *   **Bean**
# *   **Mochi**
# *   **Peanut**
# *   **Biscuit**
# *   **Pickles**
# *   **Waffles**
# *   **Pepper**
#
# ### 3. The "Nature & Earthy" Names
# Great for dogs that love the outdoors or have a calm, grounded personality.
# *   **Willow**
# *   **Bear**
# *   **River**
# *   **Sage**
# *   **Luna**
# *   **Cedar**
# *   **Daisy**
# *   **Jasper**
#
# ...

# %%
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="I've recently adopted a dog. Can you suggest some dog names?")
]

response = chat.invoke(messages)

print(response.text)
# Out:
# Congratulations on your new dog! Choosing a name is one of the most fun parts of bringing a new pet home.
#
# To help you narrow it down, I’ve broken these suggestions into a few different categories. See if any of these spark a connection:
#
# ### 1. The Classics (Timeless & Friendly)
# *   **Charlie**
# *   **Daisy**
# *   **Max**
# *   **Bella**
# *   **Cooper**
# *   **Lucy**
# *   **Buddy**
# *   **Sadie**
#
# ### 2. Human-Style Names (Very popular right now)
# *   **Finn**
# *   **Olive**
# *   **Archie**
# *   **Penny**
# *   **Teddy**
# *   **Willow**
# *   **Gus**
# *   **Hazel**
#
# ### 3. Nature & Earthy Names
# *   **Bear**
# *   **Luna**
# *   **River**
# *   **Sage**
# *   **Willow**
# *   **Aspen**
# *   **Oakley**
# *   **Daisy**
#
# ### 4. Food-Inspired (Cute & Quirky)
# *   **Bean**
# *   **Olive**
# *   **Mochi**
# *   **Peanut**
# *   **Biscuit**
# *   **Pickles**
# *   **Waffles**
# *   **Pepper**
#
# ### 5. Strong & Adventurous
# *   **Atlas**
# *   **Scout**
# ...

# %%
message_h_dog = HumanMessage(
    content="I've recently adopted a dog. Can you suggest some dog names?"
)

message_ai_dog = AIMessage(
    content="Oh, absolutely. Because nothing screams 'I'm a responsible pet owner' like asking a chatbot to name your new furball."
)

message_h_cat = HumanMessage(
    content="I've recently adopted a cat. Can you suggest some cat names?"
)

response = chat.invoke([message_h_dog, message_ai_dog, message_h_cat])

print(response.text)
# Out:
# Since you’ve moved on to the superior species, here are a few categories of names for your new cat, ranging from the dignified to the slightly unhinged:
#
# ### The "Sophisticated & Regal" Route
# *   **Barnaby:** Sounds like he owns the house and is disappointed in your choice of furniture.
# *   **Cleo:** Short for Cleopatra; perfect for a cat who expects to be worshipped.
# *   **Winston:** For a cat with a serious expression and a penchant for napping in sunbeams.
# *   **Beatrix:** Sounds like a Victorian novelist who secretly writes cat poetry.
#
# ### The "Food-Based" Route (Always a classic)
# *   **Miso:** Short, sweet, and slightly salty.
# *   **Olive:** Perfect for a cat with green eyes or a tuxedo coat.
# *   **Basil:** Sophisticated, earthy, and sounds great when you yell it across the house.
# *   **Pickle:** For a cat that is chaotic, green-eyed, or just a little bit sour.
#
# ### The "Slightly Unhinged" Route
# ...
