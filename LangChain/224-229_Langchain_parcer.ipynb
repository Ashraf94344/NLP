# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
chat = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    google_api_key="AIzaSyDsSxLzQuW_FStwDRQsZNT_NUc1JaH_ziM",
    temperature=0,
    max_output_tokens=100
)

# %%
message_h = HumanMessage(
    content="Tell about tesla"
)

response = chat.invoke([message_h])

print(response.text)
# Out:
# When people talk about "Tesla," they are usually referring to one of two things: the legendary inventor **Nikola Tesla** or the modern electric vehicle company **Tesla, Inc.** founded by Elon Musk.
#
# Here is a breakdown of both:
#
# ---
#
# ### 1. Nikola Tesla (1856–1943)
# Nikola Tesla was a Serbian-American inventor, electrical engineer, and futurist. He is one of the most important figures in

# %%
list_output_parser = CommaSeparatedListOutputParser()

# Prompt
prompt = ChatPromptTemplate.from_template(
    "Suggest 5 {pet} names separated by commas."
)

# Chain
chain = prompt | chat | list_output_parser

# Run
response_parsed = chain.invoke({"pet": "dog"})

print(response_parsed)
# Out:
# ['Luna', 'Cooper', 'Bella', 'Max', 'Daisy']

# %%
list_instructions = (
    CommaSeparatedListOutputParser()
    .get_format_instructions()
)

# Prompt template
chat_template = ChatPromptTemplate.from_messages([
    (
        "human",
        "I've recently adopted a {pet}. "
        "Could you suggest three {pet} names?\n"
        + list_instructions
    )
])

# Print template
print(chat_template.messages[0].prompt.template)
# Out:
# I've recently adopted a {pet}. Could you suggest three {pet} names?
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
list_output_parser = CommaSeparatedListOutputParser()

# Step 1: fill template
chat_template_result = chat_template.invoke({"pet": "dog"})

# Step 2: get model output
chat_result = chat.invoke(chat_template_result)

# Step 3: FIX HERE → use .content
parsed_result = list_output_parser.parse(chat_result.context)

print(parsed_result)

# %%
chain = chat_template | chat | list_output_parser

result = chain.invoke({"pet": "dog"})

print(result)
# Out:
# ['Luna', 'Cooper', 'Bailey']
