# %%
from langchain_google_genai import ChatGoogleGenerativeAI

chat = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    google_api_key="AIzaSyBzDu4oT9tbapEY89Uk6_lhvg4ui-REu24",
    temperature=0
)

response = chat.invoke("I've recently adopted a dog. Could you suggest some dog names?")

print(response.content)
# Out:
# [{'type': 'text', 'text': 'Congratulations on your new dog! Choosing a name is one of the most fun parts of bringing a new pet home.\n\nTo help you narrow it down, I’ve categorized some popular and unique names by "vibe." See if any of these spark a connection:\n\n### 1. The "Classic & Friendly" Names\nThese are timeless, easy to call out at the park, and always sound warm.\n*   **Charlie**\n*   **Daisy**\n*   **Cooper**\n*   **Bella**\n*   **Max**\n*   **Lucy**\n*   **Buddy**\n*   **Sadie**\n\n### 2. The "Foodie" Names (Very popular right now!)\nFood names are often cute, quirky, and memorable.\n*   **Olive**\n*   **Bean**\n*   **Mochi**\n*   **Peanut**\n*   **Biscuit**\n*   **Pickles**\n*   **Waffles**\n*   **Basil**\n\n### 3. The "Nature & Earthy" Names\nGreat for dogs who love the outdoors or have a calm, grounded personality.\n*   **Willow**\n*   **Bear**\n*   **River**\n*   **Sage**\n*   **Luna**\n*   **Cedar**\n*   **Daisy**\n*   **Jasper**\n\n### 4. The "Sophisticated & Human" Names\nThese names give your dog a bit of personality and charm.\n*   **Winston**\n*   **Penny**\n*   **Arthur**\n*   **Hazel**\n*   **Theodore (Theo)**\n*   **Mabel**\n*   **Oscar**\n*   **Ruby**\n\n### 5. The "Cool & Edgy" Names\nIf your dog has a bit of a "tough" or mysterious side.\n*   **Ace**\n*   **Jinx**\n*   **Rogue**\n*   **Dash**\n*   **Nova**\n*   **Axel**\n*   **Ziggy**\n*   **Echo**\n\n---\n\n### A few tips for picking the right name:\n1.  **The "Backdoor Test":** Imagine standing at your back door and yelling the name. If you feel silly or embarrassed saying it loudly, it might not be the one!\n2.  **Keep it short:** Dogs generally respond best to one or two-syllable names. They are easier for the dog to distinguish from other sounds.\n3.  **Avoid "Command" sounds:** Try to avoid names that sound like common commands (e.g., "Bo" sounds a lot like "No," or "Kit" sounds like "Sit").\n4.  **Wait a few days:** Sometimes it helps to live with your dog for 2–3 days to see what their personality is like. Are they a "Barnaby" or a "Flash"?\n\n**If you tell me a little bit about your dog—their breed, their personality (are they shy, energetic, goofy?), or even their color—I can give you some much more specific suggestions!**', 'extras': {'signature': 'EjQKMgEMOdbHw0eZ9aZ2242FwsJj019aZippaW9tkhE3EGdgsxYuoZxJWCY/s2J+rNltGah0'}}]

# %%
print(response.text)
# Out:
# Congratulations on your new dog! Choosing a name is one of the most fun parts of bringing a new pet home.
#
# To help you narrow it down, I’ve categorized some popular and unique names by "vibe." See if any of these spark a connection:
#
# ### 1. The "Classic & Friendly" Names
# These are timeless, easy to call out at the park, and always sound warm.
# *   **Charlie**
# *   **Daisy**
# *   **Cooper**
# *   **Bella**
# *   **Max**
# *   **Lucy**
# *   **Buddy**
# *   **Sadie**
#
# ### 2. The "Foodie" Names (Very popular right now!)
# Food names are often cute, quirky, and memorable.
# *   **Olive**
# *   **Bean**
# *   **Mochi**
# *   **Peanut**
# *   **Biscuit**
# *   **Pickles**
# *   **Waffles**
# *   **Basil**
#
# ### 3. The "Nature & Earthy" Names
# Great for dogs who love the outdoors or have a calm, grounded personality.
# *   **Willow**
# *   **Bear**
# *   **River**
# *   **Sage**
# *   **Luna**
# *   **Cedar**
# *   **Daisy**
# *   **Jasper**
#
# ### 4. The "Sophisticated & Human" Names
# These names give your dog a bit of personality and charm.
# *   **Winston**
# *   **Penny**
# *   **Arthur**
# *   **Hazel**
# *   **Theodore (Theo)**
# *   **Mabel**
# *   **Oscar**
# *   **Ruby**
#
# ### 5. The "Cool & Edgy" Names
# If your dog has a bit of a "tough" or mysterious side.
# *   **Ace**
# *   **Jinx**
# *   **Rogue**
# *   **Dash**
# *   **Nova**
# *   **Axel**
# *   **Ziggy**
# *   **Echo**
#
# ---
#
# ### A few tips for picking the right name:
# 1.  **The "Backdoor Test":** Imagine standing at your back door and yelling the name. If you feel silly or embarrassed saying it loudly, it might not be the one!
# 2.  **Keep it short:** Dogs generally respond best to one or two-syllable names. They are easier for the dog to distinguish from other sounds.
# 3.  **Avoid "Command" sounds:** Try to avoid names that sound like common commands (e.g., "Bo" sounds a lot like "No," or "Kit" sounds like "Sit").
# 4.  **Wait a few days:** Sometimes it helps to live with your dog for 2–3 days to see what their personality is like. Are they a "Barnaby" or a "Flash"?
#
# **If you tell me a little bit about your dog—their breed, their personality (are they shy, energetic, goofy?), or even their color—I can give you some much more specific suggestions!**

# %%
chat = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    google_api_key="AIzaSyBzDu4oT9tbapEY89Uk6_lhvg4ui-REu24",
    temperature=0,
    max_output_tokens=100
)
response = chat.invoke("I've recently adopted a dog. Could you suggest some dog names?")

print(response.text)
# Out:
# Congratulations on your new dog! Choosing a name is one of the most fun parts of bringing a new pet home.
#
# To help you narrow it down, I’ve categorized some popular and unique names by "vibe." See if any of these spark a connection:
#
# ### 1. The "Classic & Friendly" Names
# These are timeless, easy to call out at the park, and always sound warm.
# *   **Charlie**
# *   **Daisy**

# %%
chat = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    google_api_key="AIzaSyBzDu4oT9tbapEY89Uk6_lhvg4ui-REu24",
    temperature=0
)

response = chat.invoke("I've recently adopted a dog. Could you suggest some dog names?")

print(response.content)
