# %%
from langchain_core.prompts import PromptTemplate

# %%
TEMPLATE = """System: 
{description}  
Human:
I've recently adopted a {pet}. Could you suggest some {pet} names?"""

# %%
prompt_template = PromptTemplate.from_template(template = TEMPLATE)

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['description', 'pet'], input_types={}, partial_variables={}, template="System: \n{description}  \nHuman:\nI've recently adopted a {pet}. Could you suggest some {pet} names?")

# %%
prompt_value = prompt_template.invoke({'description':''' The chatbot should reluctantly answer questions with sarcastic responses. ''',  'pet':'dog'})  
prompt_value
# Out:
# StringPromptValue(text="System: \n The chatbot should reluctantly answer questions with sarcastic responses.   \nHuman:\nI've recently adopted a dog. Could you suggest some dog names?")

# %%
print(prompt_value.text)
# Out:
# System:
#  The chatbot should reluctantly answer questions with sarcastic responses.
# Human:
# I've recently adopted a dog. Could you suggest some dog names?
