# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
chat = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    google_api_key="AIzaSyBzDu4oT9tbapEY89Uk6_lhvg4ui-REu24",
    temperature=0
)

# %%
# 2. Template (THIS is what you want)
prompt = ChatPromptTemplate.from_messages([
    ("system", "{description}"),
    ("human", "I've recently adopted a {pet}. Could you suggest some {pet} names?")
])

# 3. Chain
chain = prompt | chat | StrOutputParser()

# 4. Run
response = chain.invoke({
    "description": "You are a helpful assistant.",
    "pet": "dog"
})

print(response)
# Out:
# Congratulations on your new dog! Choosing a name is such an exciting part of the process. To help you narrow it down, I’ve categorized some popular and unique names by style:
#
# ### 1. Classic & Timeless
# These names are popular for a reason—they are easy to call out at the park and never go out of style.
# *   **Male:** Charlie, Max, Cooper, Buddy, Jack, Oliver, Bear.
# *   **Female:** Bella, Daisy, Lucy, Molly, Sadie, Rosie, Maggie.
#
# ### 2. Nature-Inspired
# If your dog loves the outdoors or has an earthy personality, these are great choices.
# *   **Names:** Willow, River, Aspen, Sage, Cedar, Luna, Bear, Oakley, Hazel, Sunny, Jasper.
#
# ### 3. Food & Drink
# Food names are often cute, quirky, and memorable.
# *   **Names:** Peanut, Mochi, Olive, Basil, Biscuit, Pepper, Bean, Waffles, Pickles, Honey, Taco.
#
# ### 4. Human-Style Names
# Giving dogs "people names" has become very trendy and often makes them feel like a true member of the family.
# *   **Names:** Winston, Penny, Gus, Millie, Walter, Ruby, Arthur, Stella, George, Mabel.
#
# ### 5. Cool & Edgy
# If your dog has a bit of a "tough" or mysterious vibe.
# *   **Names:** Axel, Rogue, Diesel, Raven, Jax, Harley, Onyx, Blaze, Storm, Titan.
#
# ### 6. Pop Culture
# Inspired by movies, books, and shows.
# *   **Names:** Loki, Yoda, Khaleesi, Frodo, Winnie (the Pooh), Sherlock, Zelda, Groot, Eleven.
#
# ---
#
# ### A few tips for picking the right name:
# *   **The "Two-Syllable" Rule:** Many trainers suggest names with two syllables (like *Bai-ley* or *Char-lie*) because they are easier for dogs to distinguish from single-syllable commands like "sit" or "stay."
# *   **The "Backdoor Test":** Imagine standing at your back door and yelling the name. If you feel embarrassed saying it loudly in front of your neighbors, you might want to pick something else!
# *   **Test it out:** Pick your top two or three favorites and try them out for a day or two. See which one feels most natural when you’re talking to your dog.
#
# **To give you a more tailored recommendation, tell me a little bit about your dog:**
# 1. What breed or size are they?
# 2. What is their personality like (e.g., energetic, lazy, goofy, shy)?
# 3. What color is their coat?
